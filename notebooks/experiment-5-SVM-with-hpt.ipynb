# %%
import numpy as np
import pandas as pd
import mlflow

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_predict, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN

import optuna
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sudhirjoon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sudhirjoon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /opt/anaconda3/lib/python3.11/site-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
mlflow.set_tracking_uri("http://13.60.79.0:5000")
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# <Experiment: artifact_location='s3://capstone-yt-mlflow-bucket/542391321365143307', creation_time=1735485482149, experiment_id='542391321365143307', last_update_time=1735485482149, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={}>

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Define TF-IDF vectorization parameters
ngram_range = (1, 2)  # Bigram setting
max_features = 1000  # Set max_features to 1000 for TF-IDF

# Train-test split before vectorization and resampling
X_train, X_test, y_train, y_test = train_test_split(
    df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category']
)

# Vectorization using TF-IDF
vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
X_test_vec = vectorizer.transform(X_test)  # Transform test data

# Handle imbalance using ADASYN
adasyn = ADASYN(random_state=42)
X_train_vec, y_train = adasyn.fit_resample(X_train_vec, y_train)

# Function to log model and metrics in MLFlow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model name and experiment type
        mlflow.set_tag("mlflow.runName", f"{model_name}_ADASYN_TFIDF_Bigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log model algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model and evaluate
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log detailed classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model itself
        mlflow.sklearn.log_model(model, f"{model_name}_model")


# Optuna objective function for Support Vector Machine (SVM)
def objective_svm(trial):
    # Suggest hyperparameters
    C = trial.suggest_loguniform("C", 1e-4, 1e2)
    kernel = trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"])
    gamma = trial.suggest_categorical("gamma", ["scale", "auto"])
    
    params = {
        'C': C,
        'kernel': kernel,
        'gamma': gamma,
    }
    
    # Only add degree parameter if kernel is polynomial
    if kernel == "poly":
        params['degree'] = trial.suggest_int("degree", 1, 5)

    # Create the model with suggested parameters
    model = SVC(**params)

    # Fit the model
    model.fit(X_train_vec, y_train)

    # Calculate accuracy on the test set
    accuracy = model.score(X_test_vec, y_test)
    return accuracy

# Function to log model and metrics in MLFlow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model name and experiment type
        mlflow.set_tag("mlflow.runName", f"{model_name}_ADASYN_TFIDF_Bigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log model algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model and evaluate
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log detailed classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model itself
        mlflow.sklearn.log_model(model, f"{model_name}_model")

# Run Optuna to optimize SVM hyperparameters
def run_optuna_experiment():
    # Create an Optuna study
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_svm, n_trials=30)

    # Get the best hyperparameters and retrain the best model
    best_params = study.best_params
    
    # Create model parameters dictionary
    model_params = {
        'C': best_params['C'],
        'kernel': best_params['kernel'],
        'gamma': best_params['gamma'],
        'random_state': 42
    }
    
    # Only add degree parameter if kernel is polynomial
    if best_params['kernel'] == 'poly' and 'degree' in best_params:
        model_params['degree'] = best_params['degree']

    # Create the best model with the optimal parameters
    best_model = SVC(**model_params)

    # Log the best model with MLFlow
    log_mlflow("SVM", best_model, X_train_vec, X_test_vec, y_train, y_test)

# Run the Optuna experiment for SVM
run_optuna_experiment()
# Out:
# [I 2024-12-30 00:45:54,641] A new study created in memory with name: no-name-f64cde12-f86c-4295-aca5-aa2528dabe87
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 00:48:55,614] Trial 0 finished with value: 0.4378835401609164 and parameters: {'C': 0.010811416956509813, 'kernel': 'poly', 'gamma': 'scale', 'degree': 4}. Best is trial 0 with value: 0.4378835401609164.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 00:50:36,796] Trial 1 finished with value: 0.7804445656620755 and parameters: {'C': 1.0264700365675228, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 1 with value: 0.7804445656620755.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:11:31,640] Trial 2 finished with value: 0.5902086458475385 and parameters: {'C': 67.65233377818457, 'kernel': 'poly', 'gamma': 'scale', 'degree': 3}. Best is trial 1 with value: 0.7804445656620755.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:14:19,291] Trial 3 finished with value: 0.4301104595663439 and parameters: {'C': 0.00020624457066605568, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 1 with value: 0.7804445656620755.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:17:00,049] Trial 4 finished with value: 0.4301104595663439 and parameters: {'C': 0.0008857160933499398, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 1 with value: 0.7804445656620755.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:18:41,680] Trial 5 finished with value: 0.7818082640120005 and parameters: {'C': 1.363243781102762, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 5 with value: 0.7818082640120005.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:26:34,223] Trial 6 finished with value: 0.4301104595663439 and parameters: {'C': 0.23119396339221118, 'kernel': 'poly', 'gamma': 'auto', 'degree': 3}. Best is trial 5 with value: 0.7818082640120005.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 01:43:26,919] Trial 7 finished with value: 0.6470748670394109 and parameters: {'C': 82.39872304762764, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 5 with value: 0.7818082640120005.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:03:55,839] Trial 8 finished with value: 0.7646256648029456 and parameters: {'C': 0.2851453782104951, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 5 with value: 0.7818082640120005.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:05:33,434] Trial 9 finished with value: 0.6417564434747034 and parameters: {'C': 55.882892414487515, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 5 with value: 0.7818082640120005.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:07:46,920] Trial 10 finished with value: 0.785217509886813 and parameters: {'C': 3.4527446558920856, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 10 with value: 0.785217509886813.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:10:01,810] Trial 11 finished with value: 0.7848084003818355 and parameters: {'C': 3.419417768423131, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 10 with value: 0.785217509886813.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:12:41,805] Trial 12 finished with value: 0.7845356607118505 and parameters: {'C': 5.498340472329477, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 10 with value: 0.785217509886813.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:15:09,560] Trial 13 finished with value: 0.6881221873721532 and parameters: {'C': 0.022030755127969447, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 10 with value: 0.785217509886813.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:17:20,356] Trial 14 finished with value: 0.7853538797218055 and parameters: {'C': 3.122384843836665, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 14 with value: 0.7853538797218055.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:36:03,770] Trial 15 finished with value: 0.6793945179326333 and parameters: {'C': 9.836129707131676, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 14 with value: 0.7853538797218055.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:43:10,520] Trial 16 finished with value: 0.7498977226237556 and parameters: {'C': 0.07133538674706581, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 14 with value: 0.7853538797218055.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 02:48:51,041] Trial 17 finished with value: 0.785490249556798 and parameters: {'C': 11.835055805554036, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:08:30,656] Trial 18 finished with value: 0.7845356607118505 and parameters: {'C': 17.60860175716689, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:11:21,899] Trial 19 finished with value: 0.4301104595663439 and parameters: {'C': 0.6210710603753276, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:24:43,834] Trial 20 finished with value: 0.7850811400518205 and parameters: {'C': 15.255493814571006, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:31:42,129] Trial 21 finished with value: 0.783853811536888 and parameters: {'C': 2.3521937419954666, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:45:48,072] Trial 22 finished with value: 0.7849447702168281 and parameters: {'C': 14.103632086813311, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:47:45,460] Trial 23 finished with value: 0.7632619664530206 and parameters: {'C': 0.13875071413593695, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 17 with value: 0.785490249556798.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 03:55:04,562] Trial 24 finished with value: 0.7856266193917906 and parameters: {'C': 3.743248433607377, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 24 with value: 0.7856266193917906.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 04:15:41,685] Trial 25 finished with value: 0.7846720305468431 and parameters: {'C': 28.898383005109036, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 24 with value: 0.7856266193917906.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 04:19:31,260] Trial 26 finished with value: 0.7171689622255557 and parameters: {'C': 0.03444705819335294, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 24 with value: 0.7856266193917906.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 04:32:23,136] Trial 27 finished with value: 0.4301104595663439 and parameters: {'C': 0.4777686051021707, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 24 with value: 0.7856266193917906.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 04:39:59,223] Trial 28 finished with value: 0.4301104595663439 and parameters: {'C': 0.005021704175091506, 'kernel': 'poly', 'gamma': 'auto', 'degree': 1}. Best is trial 24 with value: 0.7856266193917906.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_42956/2531812799.py:51: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-4, 1e2)
# [I 2024-12-30 05:27:18,433] Trial 29 finished with value: 0.3752897858993591 and parameters: {'C': 7.379841978041122, 'kernel': 'poly', 'gamma': 'scale', 'degree': 5}. Best is trial 24 with value: 0.7856266193917906.
# 2024/12/30 05:45:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run SVM_ADASYN_TFIDF_Bigrams at: http://13.60.79.0:5000/#/experiments/542391321365143307/runs/e3fff0cc140b4e6683764af46ade372c
# 🧪 View experiment at: http://13.60.79.0:5000/#/experiments/542391321365143307
