# %%
import numpy as np
import pandas as pd
import mlflow

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_predict, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN

import optuna
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sudhirjoon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sudhirjoon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /opt/anaconda3/lib/python3.11/site-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
mlflow.set_tracking_uri("http://13.60.79.0:5000")
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# <Experiment: artifact_location='s3://capstone-yt-mlflow-bucket/542391321365143307', creation_time=1735485482149, experiment_id='542391321365143307', last_update_time=1735485482149, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={}>

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
display(df.head(2))
display(df.shape)
# Out:
#                                        clean_comment  category
# 0  family mormon never tried explain still stare ...         1
# 1  buddhism much lot compatible christianity espe...         1
# (36662, 2)

# %%
# Define TF-IDF vectorization parameters
ngram_range = (1, 2)  # Bigram setting
max_features = 1000  # Set max_features to 1000 for TF-IDF

# Train-test split before vectorization and resampling
X_train, X_test, y_train, y_test = train_test_split(
    df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category']
)

# Vectorization using TF-IDF
vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
X_test_vec = vectorizer.transform(X_test)  # Transform test data

# Handle imbalance using ADASYN
adasyn = ADASYN(random_state=42)
X_train_vec, y_train = adasyn.fit_resample(X_train_vec, y_train)


# Function to log model and metrics in MLFlow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model name and experiment type
        mlflow.set_tag("mlflow.runName", f"{model_name}_ADASYN_TFIDF_Bigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log model algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model and evaluate
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log detailed classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model itself
        mlflow.sklearn.log_model(model, f"{model_name}_model")


# Optuna objective function for Multinomial Naive Bayes
def objective_nb(trial):
    # Suggest hyperparameters for MultinomialNB
    alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)

    # Initialize the MultinomialNB model
    model = MultinomialNB(alpha=alpha)

    # Train and evaluate the model
    model.fit(X_train_vec, y_train)
    y_pred = model.predict(X_test_vec)
    accuracy = accuracy_score(y_test, y_pred)

    return accuracy

# Function to log model and metrics in MLFlow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model name and experiment type
        mlflow.set_tag("mlflow.runName", f"{model_name}_ADASYN_TFIDF_Bigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log model algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model and evaluate
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log detailed classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model itself
        mlflow.sklearn.log_model(model, f"{model_name}_model")

# Run Optuna to optimize Multinomial Naive Bayes hyperparameters
def run_optuna_experiment():
    # Create an Optuna study
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_nb, n_trials=30)

    # Get the best hyperparameters and retrain the best model
    best_params = study.best_params
    best_model = MultinomialNB(alpha=best_params['alpha'])

    # Log the best model with MLFlow
    log_mlflow("MultinomialNB", best_model, X_train_vec, X_test_vec, y_train, y_test)

# Run the Optuna experiment for Multinomial Naive Bayes
run_optuna_experiment()
# Out:
# [I 2024-12-30 14:31:09,114] A new study created in memory with name: no-name-6b304a7c-2451-4402-882e-8e26629e3b9a
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,129] Trial 0 finished with value: 0.6463930178644484 and parameters: {'alpha': 0.15316053992413495}. Best is trial 0 with value: 0.6463930178644484.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,138] Trial 1 finished with value: 0.6483021955543434 and parameters: {'alpha': 3.069023618544049e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,146] Trial 2 finished with value: 0.6465293876994409 and parameters: {'alpha': 0.11565995549714665}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,155] Trial 3 finished with value: 0.6481658257193509 and parameters: {'alpha': 0.00031417532456183973}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,163] Trial 4 finished with value: 0.6478930860493659 and parameters: {'alpha': 0.003256975592895256}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,172] Trial 5 finished with value: 0.6483021955543434 and parameters: {'alpha': 0.00011077983751769896}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,181] Trial 6 finished with value: 0.6478930860493659 and parameters: {'alpha': 0.0021877705025979697}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,191] Trial 7 finished with value: 0.6414837038047184 and parameters: {'alpha': 0.7395329377116665}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,199] Trial 8 finished with value: 0.6480294558843583 and parameters: {'alpha': 0.0009641838122868609}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,210] Trial 9 finished with value: 0.6466657575344333 and parameters: {'alpha': 0.07975529421493444}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,227] Trial 10 finished with value: 0.6483021955543434 and parameters: {'alpha': 2.6303939830785243e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,241] Trial 11 finished with value: 0.6483021955543434 and parameters: {'alpha': 1.0964660292572653e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,254] Trial 12 finished with value: 0.6483021955543434 and parameters: {'alpha': 8.375576509453647e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,268] Trial 13 finished with value: 0.6483021955543434 and parameters: {'alpha': 7.918209490082067e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,281] Trial 14 finished with value: 0.6481658257193509 and parameters: {'alpha': 0.00026159619293320073}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,294] Trial 15 finished with value: 0.6483021955543434 and parameters: {'alpha': 7.320389635404486e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,306] Trial 16 finished with value: 0.6476203463793809 and parameters: {'alpha': 0.010639455061001812}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,319] Trial 17 finished with value: 0.6483021955543434 and parameters: {'alpha': 1.758191923581558e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,333] Trial 18 finished with value: 0.6481658257193509 and parameters: {'alpha': 0.00030511275142264385}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,347] Trial 19 finished with value: 0.6483021955543434 and parameters: {'alpha': 4.2456444163636685e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,362] Trial 20 finished with value: 0.6476203463793809 and parameters: {'alpha': 0.016652703356462153}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,376] Trial 21 finished with value: 0.6483021955543434 and parameters: {'alpha': 2.6548472791528303e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,389] Trial 22 finished with value: 0.6481658257193509 and parameters: {'alpha': 0.0001567830854355082}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,402] Trial 23 finished with value: 0.6483021955543434 and parameters: {'alpha': 1.3796891148156204e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,416] Trial 24 finished with value: 0.6480294558843583 and parameters: {'alpha': 0.0008557286785199879}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,430] Trial 25 finished with value: 0.6483021955543434 and parameters: {'alpha': 3.712348717439455e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,445] Trial 26 finished with value: 0.6480294558843583 and parameters: {'alpha': 0.0006852675792625006}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,458] Trial 27 finished with value: 0.6483021955543434 and parameters: {'alpha': 0.00012614752541618981}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,471] Trial 28 finished with value: 0.6483021955543434 and parameters: {'alpha': 3.3219349327587915e-05}. Best is trial 1 with value: 0.6483021955543434.
# /var/folders/yj/2fr85zvn2sbbpv3jsq4y3kwh0000gn/T/ipykernel_51639/2492944611.py:52: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("alpha", 1e-5, 1.0)  # Smoothing parameter (Laplace smoothing)
# [I 2024-12-30 14:31:09,485] Trial 29 finished with value: 0.6483021955543434 and parameters: {'alpha': 1.0740526209608648e-05}. Best is trial 1 with value: 0.6483021955543434.
# 2024/12/30 14:31:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run MultinomialNB_ADASYN_TFIDF_Bigrams at: http://13.60.79.0:5000/#/experiments/542391321365143307/runs/c6de7fd73c944418ba88e9a4d2bafdcd
# 🧪 View experiment at: http://13.60.79.0:5000/#/experiments/542391321365143307
